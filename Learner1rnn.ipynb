# %%
from keras.utils import plot_model
import threading
import time
# INITIALIZATION: libraries, parameters, network...

from keras.models import Sequential      # One layer after the other
from keras.layers import Dense, Flatten  # Dense layers are fully connected layers, Flatten layers flatten out multidimensional inputs
from collections import deque            # For storing moves 
import World
import numpy as np
import gym                                # To train our network

import tensorflow as tf
import random
# Out:
# Using TensorFlow backend.

# %%
# For sampling batches from the observations


    # Parameters
D = deque()                                # Register where the actions will be stored

observetime = 500                          # Number of timesteps we will be acting on the game and observing results
epsilon = 0.9                              # Probability of doing a random move
gamma = 0.9                                # Discounted future reward. How much we care about steps further in time
mb_size = 60     

class Q_Network():
    def __init__(self,scope):
        with tf.variable_scope(scope):
                    self.input_p = tf.placeholder(tf.float32, [None,5])
                    self.q_target = tf.placeholder(tf.float32, [None ,4], name='Q_target')
                    self.w1 = tf.get_variable('w1', [5,15], initializer=tf.random_uniform_initializer())
                    self.b1 = tf.get_variable('b1', [1,15], initializer=tf.zeros_initializer())
                    self.l1 = tf.nn.relu(tf.matmul(self.input_p,self.w1 ) + self.b1)

                    self.w2 = tf.get_variable('w2', [15, 15], initializer=tf.random_uniform_initializer())
                    self.b2 = tf.get_variable('b2', [1, 15], initializer=tf.zeros_initializer())
                    self.l2 = tf.nn.relu(tf.matmul(self.l1,self.w2) + self.b2)

                    self.w3 = tf.get_variable('w3', [15,4], initializer=tf.random_uniform_initializer())
                    self.b3 = tf.get_variable('b3', [1,4], initializer=tf.zeros_initializer())
                    self.Q = (tf.matmul(self.l2,self.w3) + self.b3)
                    
                    self.sqd=tf.squared_difference(self.q_target, self.Q)
                    self.loss = tf.reduce_mean(self.sqd)       
                    self.trainer = tf.train.RMSPropOptimizer(learning_rate=0.01)
                    self.updateModel = self.trainer.minimize(self.loss)        
# model = Sequential()
# model.add(Dense(10, input_shape=(5,) , init='uniform', activation='relu'))
#     #model.add(Flatten())       # Flatten input so as to have no problems with processing
# model.add(Dense(10, init='uniform', activation='relu'))
# model.add(Dense(4, init='uniform', activation='linear'))    # Same number of outputs as possible actions

# model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
# plot_model(model, to_file='model.png',show_shapes=True)
                          # Learning minibatch size

# %%
def do_action(action):
    #r = -World.score
    if action == 0:
        rew,s,s1,res=World.try_move(0, -1)
    elif action == 1:
        rew,s,s1,res=World.try_move(0, 1)
    elif action == 2:
        rew,s,s1,res=World.try_move(-1, 0)
    elif action == 3:
        rew,s,s1,res=World.try_move(1, 0)
    #r += World.score
    return rew,s,s1,res

# %%
def updateNetwork(target,main):
    a1=tf.assign(target.w1,main.w1.value())
    a2=tf.assign(target.w2,main.w2.value())
    a3=tf.assign(target.w3,main.w3.value())
    a4=tf.assign(target.b1,main.b1.value())
    a5=tf.assign(target.b2,main.b2.value())
    a6=tf.assign(target.b3,main.b3.value())
    return a1,a2,a3,a4,a5,a6

# %%
# FIRST STEP: Knowing what each action does (Observing)
def observe(sess,main):
    done = False
    state=World.findState()
    for t in range(observetime):
        if np.random.rand() <= epsilon:
            action = np.random.randint(0, 4)
        else:
            Qs = sess.run(main.Q,feed_dict={main.input_p:state})          # Q-values predictions
            action = np.argmax(Qs,axis=1)[0]             # Move with highest Q-value is the chosen one
        reward,state,state_new,res = do_action(action)     # See state of the game, reward... after performing the action
                 # Update the input with the new state of the game
        D.append((state, action, reward, state_new, res))
            
    print('Observing Finished')

# %%
# SECOND STEP: Learning from the observations (Experience replay)

                            # Sample some moves

def learn(sess,main,target):
    inputs = np.zeros((mb_size,5))
    targets = np.zeros((mb_size, 4))
    for j in range(5):
        minibatch = random.sample(D, mb_size) 
        for i in range(mb_size):
            state = minibatch[i][0]
            action = minibatch[i][1]
            reward = minibatch[i][2]
            state_new = minibatch[i][3]
            done = minibatch[i][4]

    # Build Bellman equation for the Q function
            inputs[i:i+1] = state   # Q-values predictions

            targets[i] = sess.run(target.Q,feed_dict={target.input_p:state})
            Q_sa = sess.run(main.Q,feed_dict={main.input_p:state_new})
            if done:
                targets[i, action] = reward
            else:
                targets[i, action] = reward + gamma * np.max(Q_sa,axis=1)
                
        a,b=sess.run([main.updateModel,main.loss],feed_dict={main.input_p:inputs,main.q_target:targets})
        print("Cost",b)
    sess.run(updateNetwork(target,main))    
    # Train network to output the Q function
    D.clear()
       
    print('Learning Finished')
    #print(inputs,targets)

# %%
# THIRD STEP: Play!
def test(sess,main):
    print("Evaluating")
    World.restart=True
    s1 = World.findState()
    done = False
    tot_reward = 0.0
    i=0
    while i<50:                 # Uncomment to see game running
        Qs = sess.run(main.Q,feed_dict={main.input_p:s1})
        action = np.argmax(Qs,axis=1)   
        #print(Q,action)
        rew,s,s1,res = do_action(action[0]) 
        tot_reward += rew
        print('Game : ',action,"   reward ",rew,"state",s,res)
        i+=1
        time.sleep(0.1)
        if res:
            break
    print('Game ended! Total reward: {}'.format(tot_reward))

# %%
class MyThread(threading.Thread):
    def run(self):
        process()

# %%
f=False

def process():
    global epsilon,f
    main=Q_Network('main')
    target=Q_Network('target')
    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        for i in range(200):
            print('iteration ',i)
            World.restart=True
            observe(sess,main)
            learn(sess,main,target)
            if(i>150):
                World.start()
                test(sess,main)
                World.pause()
            epsilon -=0.03                              
t = MyThread()
t.daemon = True
t.start() 
World.start_game()
# Out:
# iteration  0
# Observing Finished
# Cost 407599.0
# Cost 219143.0
# Cost 137906.0
# Cost 111686.0
# Cost 143702.0
# Learning Finished
# iteration  1
# Observing Finished
# Cost 99055.0
# Cost 116457.0
# Cost 107038.0
# Cost 92052.3
# Cost 88811.2
# Learning Finished
# iteration  2
# Observing Finished
# Cost 66272.7
# Cost 61279.2
# Cost 84009.4
# Cost 60226.7
# Cost 54187.9
# Learning Finished
# iteration  3
# Observing Finished
# Cost 66751.4
# Cost 45115.5
# Cost 41751.8
# Cost 44139.9
# Cost 47581.3
# Learning Finished
# iteration  4
# Observing Finished
# Cost 14162.9
# Cost 18517.6
# Cost 9760.52
# Cost 12850.8
# Cost 12962.5
# Learning Finished
# iteration  5
# Observing Finished
# Cost 11533.7
# Cost 10038.2
# Cost 14393.2
# Cost 21502.9
# Cost 4903.22
# Learning Finished
# iteration  6
# Observing Finished
# Cost 63255.3
# Cost 45288.6
# Cost 57191.0
# Cost 47831.8
# Cost 41647.1
# Learning Finished
# iteration  7
# Observing Finished
# Cost 3822.04
# Cost 3654.53
# Cost 7883.15
# Cost 9150.72
# Cost 10758.6
# Learning Finished
# iteration  8
# Observing Finished
# Cost 5751.94
# Cost 8972.07
# Cost 7096.93
# Cost 8219.93
# Cost 5569.06
# Learning Finished
# iteration  9
# Observing Finished
# Cost 3812.27
# Cost 6274.53
# Cost 7480.85
# Cost 5878.91
# Cost 7728.4
# Learning Finished
# iteration  10
# Observing Finished
# Cost 2923.28
# Cost 5410.09
# Cost 5950.63
# Cost 8436.36
# Cost 3344.45
# Learning Finished
# iteration  11
# Observing Finished
# Cost 7037.43
# Cost 9199.08
# Cost 10792.1
# Cost 7792.37
# Cost 8813.38
# Learning Finished
# iteration  12
# Observing Finished
# Cost 4821.27
# Cost 2442.81
# Cost 3505.57
# Cost 3271.91
# Cost 1492.48
# Learning Finished
# iteration  13
# Observing Finished
# Cost 6118.3
# Cost 4948.77
# Cost 4320.14
# Cost 5485.1
# Cost 7345.43
# Learning Finished
# iteration  14
# Observing Finished
# Cost 26630.9
# Cost 20393.4
# Cost 17167.5
# Cost 20844.2
# Cost 17585.3
# Learning Finished
# iteration  15
# Observing Finished
# Cost 4934.49
# Cost 2781.93
# Cost 2680.59
# Cost 1715.34
# Cost 2156.97
# Learning Finished
# iteration  16
# Observing Finished
# Cost 2043.62
# Cost 1237.41
# Cost 3123.88
# Cost 2426.67
# Cost 2552.85
# Learning Finished
# iteration  17
# Observing Finished
# Cost 2793.06
# Cost 1610.06
# Cost 3142.93
# Cost 807.987
# Cost 2852.04
# Learning Finished
# iteration  18
# Observing Finished
# Cost 1604.76
# Cost 1922.58
# Cost 1568.86
# Cost 2405.78
# Cost 1392.27
# Learning Finished
# iteration  19
# Observing Finished
# Cost 1719.73
# Cost 1642.46
# Cost 2471.38
# Cost 1990.95
# Cost 1781.21
# Learning Finished
# iteration  20
# Observing Finished
# Cost 2443.99
# Cost 2984.53
# Cost 3421.51
# Cost 2641.42
# Cost 2955.84
# Learning Finished
# iteration  21
# Observing Finished
# Cost 843.625
# Cost 900.189
# Cost 887.741
# Cost 880.878
# Cost 795.492
# Learning Finished
# iteration  22
# Observing Finished
# Cost 6137.37
# Cost 5006.16
# Cost 4419.84
# Cost 2793.68
# Cost 4751.28
# Learning Finished
# iteration  23
# Observing Finished
# Cost 8873.29
# Cost 5585.34
# Cost 4954.11
# Cost 4275.71
# Cost 3775.16
# Learning Finished
# iteration  24
# Observing Finished
# Cost 554.56
# Cost 638.795
# Cost 562.709
# Cost 416.249
# Cost 416.443
# Learning Finished
# iteration  25
# Observing Finished
# Cost 465.722
# Cost 175.589
# Cost 357.398
# Cost 357.646
# Cost 307.525
# Learning Finished
# iteration  26
# Observing Finished
# Cost 591.734
# Cost 330.353
# Cost 350.09
# Cost 391.089
# Cost 140.255
# Learning Finished
# iteration  27
# Observing Finished
# Cost 316.718
# Cost 198.585
# Cost 438.907
# Cost 423.614
# Cost 308.784
# Learning Finished
# iteration  28
# Observing Finished
# Cost 124.914
# Cost 112.994
# Cost 189.651
# Cost 149.457
# Cost 138.473
# Learning Finished
# iteration  29
# Observing Finished
# Cost 188.462
# Cost 169.231
# Cost 133.952
# Cost 134.516
# Cost 97.2837
# Learning Finished
# iteration  30
# Observing Finished
# Cost 23.5071
# Cost 55.7088
# Cost 18.7757
# Cost 49.2727
# Cost 17.1509
# Learning Finished
# iteration  31
# Observing Finished
# Cost 204.223
# Cost 113.573
# Cost 131.362
# Cost 87.8983
# Cost 77.8897
# Learning Finished
# iteration  32
# Observing Finished
# Cost 732.006
# Cost 604.993
# Cost 574.612
# Cost 493.076
# Cost 475.874
# Learning Finished
# iteration  33
# Observing Finished
# Cost 2344.68
# Cost 1449.38
# Cost 1128.42
# Cost 911.625
# Cost 744.309
# Learning Finished
# iteration  34
# Observing Finished
# Cost 37.8111
# Cost 86.8643
# Cost 36.9112
# Cost 82.3639
# Cost 246.689
# Learning Finished
# iteration  35
# Observing Finished
# Cost 16.8595
# Cost 32.3811
# Cost 11.112
# Cost 17.8561
# Cost 9.54585
# Learning Finished
# iteration  36
# Observing Finished
# Cost 47.9708
# Cost 103.206
# Cost 176.631
# Cost 53.428
# Cost 125.799
# Learning Finished
# iteration  37
# Observing Finished
# Cost 42.6484
# Cost 35.8518
# Cost 38.1637
# Cost 26.5511
# Cost 40.8075
# Learning Finished
# iteration  38
# Observing Finished
# Cost 95.6226
# Cost 103.624
# Cost 76.4612
# Cost 60.4118
# Cost 58.9216
# Learning Finished
# iteration  39
# Observing Finished
# Cost 6.04363
# Cost 10.4048
# Cost 3.74718
# Cost 6.58106
# Cost 3.40779
# Learning Finished
# iteration  40
# Observing Finished
# Cost 7.91756
# Cost 30.3606
# Cost 25.5645
# Cost 54.1761
# Cost 14.6002
# Learning Finished
# iteration  41
# Observing Finished
# Cost 104.728
# Cost 66.6108
# Cost 35.3707
# Cost 19.9136
# Cost 38.1246
# Learning Finished
# iteration  42
# Observing Finished
# Cost 36.0135
# Cost 50.7671
# Cost 33.4406
# Cost 25.5739
# Cost 20.4209
# Learning Finished
# iteration  43
# Observing Finished
# Cost 51.1397
# Cost 50.0366
# Cost 40.9021
# Cost 38.8493
# Cost 51.5231
# Learning Finished
# iteration  44
# Observing Finished
# Cost 2.49441
# Cost 4.23592
# Cost 2.00009
# Cost 4.05205
# Cost 5.30088
# Learning Finished
# iteration  45
# Observing Finished
# Cost 3.22882
# Cost 9.26283
# Cost 7.35124
# Cost 16.4398
# Cost 5.0485
# Learning Finished
# iteration  46
# Observing Finished
# Cost 10.3011
# Cost 12.2404
# Cost 9.30215
# Cost 10.3496
# Cost 13.6925
# Learning Finished
# iteration  47
# Observing Finished
# Cost 4.25311
# Cost 6.66993
# Cost 6.6787
# Cost 15.0586
# Cost 4.73764
# Learning Finished
# iteration  48
# Observing Finished
# Cost 13.5282
# Cost 26.5458
# Cost 11.8742
# Cost 22.3686
# Cost 20.3352
# Learning Finished
# iteration  49
# Observing Finished
# Cost 9.04233
# Cost 9.44139
# Cost 7.23517
# Cost 5.23722
# Cost 5.90574
# Learning Finished
# iteration  50
# Observing Finished
# Cost 1.78201
# Cost 3.16961
# Cost 1.65632
# Cost 4.87073
# Cost 2.44062
# Learning Finished
# iteration  51
# Observing Finished
# Cost 1.15367
# Cost 2.76466
# Cost 1.24285
# Cost 5.00182
# Cost 2.68856
# Learning Finished
# iteration  52
# Observing Finished
# Cost 1.01272
# Cost 1.32227
# Cost 0.552943
# Cost 1.24072
# Cost 0.525934
# Learning Finished
# iteration  53
# Observing Finished
# Cost 0.76069
# Cost 1.14437
# Cost 0.520818
# Cost 1.26871
# Cost 0.693689
# Learning Finished
# iteration  54
# Observing Finished
# Cost 0.828247
# Cost 1.26227
# Cost 0.681463
# Cost 0.915244
# Cost 0.772209
# Learning Finished
# iteration  55
# Observing Finished
# Cost 0.780165
# Cost 1.60878
# Cost 2.37482
# Cost 5.73219
# Cost 1.59916
# Learning Finished
# iteration  56
# Observing Finished
# Cost 0.452106
# Cost 0.594418
# Cost 0.42281
# Cost 0.422954
# Cost 0.388979
# Learning Finished
# iteration  57
# Observing Finished
# Cost 2.89849
# Cost 3.38327
# Cost 4.96208
# Cost 6.01343
# Cost 1.37467
# Learning Finished
# iteration  58
# Observing Finished
# Cost 3.49058
# Cost 3.55952
# Cost 2.71411
# Cost 2.59506
# Cost 1.97118
# Learning Finished
# iteration  59
# Observing Finished
# Cost 4.32368
# Cost 3.06952
# Cost 3.17786
# Cost 3.79081
# Cost 2.85442
# Learning Finished
# iteration  60
# Observing Finished
# Cost 2.6445
# Cost 1.24331
# Cost 2.91582
# Cost 1.40697
# Cost 1.97282
# Learning Finished
# iteration  61
# Observing Finished
# Cost 0.351321
# Cost 0.53566
# Cost 0.354841
# Cost 0.423251
# Cost 0.306548
# Learning Finished
# iteration  62
# Observing Finished
# Cost 0.228112
# Cost 0.502559
# Cost 0.488742
# Cost 1.87403
# Cost 1.59608
# Learning Finished
# iteration  63
# Observing Finished
# Cost 0.823787
# Cost 1.11928
# Cost 0.778501
# Cost 0.505722
# Cost 0.622718
# Learning Finished
# iteration  64
# Observing Finished
# Cost 0.196674
# Cost 0.182369
# Cost 0.162941
# Cost 0.164046
# Cost 0.213281
# Learning Finished
# iteration  65
# Observing Finished
# Cost 0.195943
# Cost 0.278691
# Cost 0.211048
# Cost 0.228975
# Cost 0.286946
# Learning Finished
# iteration  66
# Observing Finished
# Cost 1.84889
# Cost 1.62969
# Cost 1.34048
# Cost 1.63411
# Cost 1.39873
# Learning Finished
# iteration  67
# Observing Finished
# Cost 0.132943
# Cost 0.180635
# Cost 0.17647
# Cost 0.326956
# Cost 0.360009
# Learning Finished
# iteration  68
# Observing Finished
# Cost 0.243466
# Cost 0.239656
# Cost 0.162043
# Cost 0.148917
# Cost 0.141976
# Learning Finished
# iteration  69
# Observing Finished
# Cost 0.136934
# Cost 0.21173
# Cost 0.153054
# Cost 0.328833
# Cost 0.297725
# Learning Finished
# iteration  70
# Observing Finished
# Cost 0.103144
# Cost 0.161771
# Cost 0.156204
# Cost 0.258248
# Cost 0.201683
# Learning Finished
# iteration  71
# Observing Finished
# Cost 0.245521
# Cost 1.98394
# Cost 1.42755
# Cost 0.623491
# Cost 0.14991
# Learning Finished
# iteration  72
# Observing Finished
# Cost 0.716162
# Cost 0.347286
# Cost 0.558043
# Cost 0.402241
# Cost 0.312993
# Learning Finished
# iteration  73
# Observing Finished
# Cost 0.0593878
# Cost 0.0452531
# Cost 0.0462186
# Cost 0.103009
# Cost 0.0763346
# Learning Finished
# iteration  74
# Observing Finished
# Cost 0.145296
# Cost 0.133501
# Cost 0.147513
# Cost 0.215885
# Cost 0.0601748
# Learning Finished
# iteration  75
# Observing Finished
# Cost 0.0383993
# Cost 0.0612665
# Cost 0.0498725
# Cost 0.046352
# Cost 0.041644
# Learning Finished
# iteration  76
# Observing Finished
# Cost 0.49547
# Cost 0.330442
# Cost 0.220879
# Cost 0.476109
# Cost 0.280521
# Learning Finished
# iteration  77
# Observing Finished
# Cost 0.0475894
# Cost 0.177196
# Cost 0.705874
# Cost 0.555167
# Cost 0.0711306
# Learning Finished
# iteration  78
# Observing Finished
# Cost 0.248173
# Cost 0.285051
# Cost 0.388402
# Cost 0.410726
# Cost 0.287473
# Learning Finished
# iteration  79
# Observing Finished
# Cost 0.0668378
# Cost 0.147979
# Cost 0.153246
# Cost 0.57875
# Cost 0.423045
# Learning Finished
# iteration  80
# Observing Finished
# Cost 0.403703
# Cost 0.276899
# Cost 0.258187
# Cost 0.242516
# Cost 0.21941
# Learning Finished
# iteration  81
# Observing Finished
# Cost 0.0920678
# Cost 0.074279
# Cost 0.0831615
# Cost 0.0806455
# Cost 0.111766
# Learning Finished
# iteration  82
# Observing Finished
# Cost 0.0697999
# Cost 0.143736
# Cost 0.46476
# Cost 0.623229
# Cost 0.217195
# Learning Finished
# iteration  83
# Observing Finished
# Cost 0.325514
# Cost 0.0974957
# Cost 0.124864
# Cost 0.0412473
# Cost 0.0775494
# Learning Finished
# iteration  84
# Observing Finished
# Cost 0.0320733
# Cost 0.06236
# Cost 0.0325173
# Cost 0.0368818
# Cost 0.0310224
# Learning Finished
# iteration  85
# Observing Finished
# Cost 0.127021
# Cost 0.139677
# Cost 0.0451843
# Cost 0.115797
# Cost 0.115379
# Learning Finished
# iteration  86
# Observing Finished
# Cost 0.0582289
# Cost 0.146724
# Cost 0.115085
# Cost 0.175963
# Cost 0.189295
# Learning Finished
# iteration  87
# Observing Finished
# Cost 0.0805532
# Cost 0.129534
# Cost 0.0765251
# Cost 0.0644249
# Cost 0.093706
# Learning Finished
# iteration  88
# Observing Finished
# Cost 0.0637541
# Cost 0.19886
# Cost 0.373847
# Cost 0.112617
# Cost 0.0841639
# Learning Finished
# iteration  89
# Observing Finished
# Cost 0.0781284
# Cost 0.0679935
# Cost 0.0284113
# Cost 0.047014
# Cost 0.061933
# Learning Finished
# iteration  90
# Observing Finished
# Cost 0.0210122
# Cost 0.0655001
# Cost 0.0663238
# Cost 0.0119543
# Cost 0.00923195
# Learning Finished
# iteration  91
# Observing Finished
# Cost 0.0542617
# Cost 0.0602639
# Cost 0.0730599
# Cost 0.0605633
# Cost 0.0639955
# Learning Finished
# iteration  92
# Observing Finished
# Cost 0.0516562
# Cost 0.172987
# Cost 0.351982
# Cost 0.453571
# Cost 0.133456
# Learning Finished
# iteration  93
# Observing Finished
# Cost 0.0107587
# Cost 0.039956
# Cost 0.0218245
# Cost 0.0106852
# Cost 0.04749
# Learning Finished
# iteration  94
# Observing Finished
# Cost 0.0207022
# Cost 0.0214914
# Cost 0.0193239
# Cost 0.0305212
# Cost 0.00860215
# Learning Finished
# iteration  95
# Observing Finished
# Cost 0.0177082
# Cost 0.0435503
# Cost 0.036812
# Cost 0.0693287
# Cost 0.019928
# Learning Finished
# iteration  96
# Observing Finished
# Cost 0.0254216
# Cost 0.0601174
# Cost 0.0647066
# Cost 0.0879774
# Cost 0.170056
# Learning Finished
# iteration  97
# Observing Finished
# Cost 0.0305873
# Cost 0.0414862
# Cost 0.015855
# Cost 0.0213354
# Cost 0.0190081
# Learning Finished
# iteration  98
# Observing Finished
# Cost 0.0159681
# Cost 0.0299829
# Cost 0.0165174
# Cost 0.024939
# Cost 0.0201471
# Learning Finished
# iteration  99
# Observing Finished
# Cost 0.0231558
# Cost 0.0223953
# Cost 0.0112441
# Cost 0.0185088
# Cost 0.00972924
# Learning Finished
# iteration  100
# Observing Finished
# Cost 0.0128033
# Cost 0.00726066
# Cost 0.00891459
# Cost 0.00968463
# Cost 0.0275518
# Learning Finished
# iteration  101
# Observing Finished
# Cost 0.00974962
# Cost 0.0210435
# Cost 0.0179132
# Cost 0.0334814
# Cost 0.0176173
# Learning Finished
# iteration  102
# Observing Finished
# Cost 0.0545092
# Cost 0.0496848
# Cost 0.0484239
# Cost 0.0442235
# Cost 0.0477447
# Learning Finished
# iteration  103
# Observing Finished
# Cost 0.0153233
# Cost 0.02086
# Cost 0.0183969
# Cost 0.0500758
# Cost 0.0196242
# Learning Finished
# iteration  104
# Observing Finished
# Cost 0.0164116
# Cost 0.0120006
# Cost 0.0113226
# Cost 0.0210499
# Cost 0.0107813
# Learning Finished
# iteration  105
# Observing Finished
# Cost 0.00532195
# Cost 0.0097384
# Cost 0.011999
# Cost 0.0171562
# Cost 0.0179459
# Learning Finished
# iteration  106
# Observing Finished
# Cost 0.00994678
# Cost 0.0122326
# Cost 0.0135849
# Cost 0.0252973
# Cost 0.0323389
# Learning Finished
# iteration  107
# Observing Finished
# Cost 0.0118763
# Cost 0.0214118
# Cost 0.0105192
# Cost 0.00940658
# Cost 0.00798656
# Learning Finished
# iteration  108
# Observing Finished
# Cost 0.0160354
# Cost 0.0817591
# Cost 0.133612
# Cost 0.054812
# Cost 0.0395004
# Learning Finished
# iteration  109
# Observing Finished
# Cost 0.00364647
# Cost 0.00604731
# Cost 0.00575672
# Cost 0.00402413
# Cost 0.0079353
# Learning Finished
# iteration  110
# Observing Finished
# Cost 0.0117961
# Cost 0.0135008
# Cost 0.00959793
# Cost 0.0116414
# Cost 0.00650312
# Learning Finished
# iteration  111
# Observing Finished
# Cost 0.0148872
# Cost 0.00845266
# Cost 0.0110591
# Cost 0.00347853
# Cost 0.00608868
# Learning Finished
# iteration  112
# Observing Finished
# Cost 0.00632839
# Cost 0.011955
# Cost 0.00691614
# Cost 0.00921172
# Cost 0.0098928
# Learning Finished
# iteration  113
# Observing Finished
# Cost 0.005948
# Cost 0.00312705
# Cost 0.00632295
# Cost 0.0114444
# Cost 0.0124518
# Learning Finished
# iteration  114
# Observing Finished
# Cost 0.00723552
# Cost 0.0121412
# Cost 0.0683114
# Cost 0.0352182
# Cost 0.027168
# Learning Finished
# iteration  115
# Observing Finished
# Cost 0.00305574
# Cost 0.0158316
# Cost 0.00760426
# Cost 0.00775489
# Cost 0.00580702
# Learning Finished
# iteration  116
# Observing Finished
# Cost 0.0123738
# Cost 0.0318349
# Cost 0.0580576
# Cost 0.0559944
# Cost 0.0084813
# Learning Finished
# iteration  117
# Observing Finished
# Cost 0.0118799
# Cost 0.0265824
# Cost 0.0124811
# Cost 0.0261246
# Cost 0.0428679
# Learning Finished
# iteration  118
# Observing Finished
# Cost 0.00224864
# Cost 0.00565842
# Cost 0.0037666
# Cost 0.00734585
# Cost 0.00786915
# Learning Finished
# iteration  119
# Observing Finished
# Cost 0.00481164
# Cost 0.00495655
# Cost 0.00386451
# Cost 0.00426351
# Cost 0.00385196
# Learning Finished
# iteration  120
# Observing Finished
# Cost 0.00729212
# Cost 0.00736722
# Cost 0.00568162
# Cost 0.00611791
# Cost 0.00628441
# Learning Finished
# iteration  121
# Observing Finished
# Cost 0.0099764
# Cost 0.0143639
# Cost 0.00484843
# Cost 0.00805333
# Cost 0.00458116
# Learning Finished
# iteration  122
# Observing Finished
# Cost 0.00605688
# Cost 0.00826716
# Cost 0.00668257
# Cost 0.00650975
# Cost 0.00586252
# Learning Finished
# iteration  123
# Observing Finished
# Cost 0.00144094
# Cost 0.00314152
# Cost 0.00167636
# Cost 0.00143865
# Cost 0.00149212
# Learning Finished
# iteration  124
# Observing Finished
# Cost 0.00407004
# Cost 0.00242334
# Cost 0.00323401
# Cost 0.00245003
# Cost 0.0033657
# Learning Finished
# iteration  125
# Observing Finished
# Cost 0.00369998
# Cost 0.00342535
# Cost 0.00337407
# Cost 0.00323599
# Cost 0.00213721
# Learning Finished
# iteration  126
# Observing Finished
# Cost 0.00603499
# Cost 0.00417273
# Cost 0.00558961
# Cost 0.00593292
# Cost 0.00450316
# Learning Finished
# iteration  127
# Observing Finished
# Cost 0.0075907
# Cost 0.0139676
# Cost 0.00915446
# Cost 0.00886036
# Cost 0.00699915
# Learning Finished
# iteration  128
# Observing Finished
# Cost 0.00110769
# Cost 0.000270929
# Cost 0.00218212
# Cost 0.00206412
# Cost 0.00196911
# Learning Finished
# iteration  129
# Observing Finished
# Cost 0.00242803
# Cost 0.000811384
# Cost 0.00164421
# Cost 0.00182878
# Cost 0.00226213
# Learning Finished
# iteration  130
# Observing Finished
# Cost 0.00154774
# Cost 0.00147364
# Cost 0.00267999
# Cost 0.00181184
# Cost 0.00139634
# Learning Finished
# iteration  131
# Observing Finished
# Cost 0.00129855
# Cost 0.000952291
# Cost 0.00239812
# Cost 0.00145358
# Cost 0.00133225
# Learning Finished
# iteration  132
# Observing Finished
# Cost 0.00111187
# Cost 0.00151555
# Cost 0.00285536
# Cost 0.00252832
# Cost 0.0016751
# Learning Finished
# iteration  133
# Observing Finished
# Cost 0.00250336
# Cost 0.00153765
# Cost 0.00206134
# Cost 0.00390205
# Cost 0.00293986
# Learning Finished
# iteration  134
# Observing Finished
# Cost 0.00152387
# Cost 0.00118321
# Cost 0.00194454
# Cost 0.0022165
# Cost 0.00112722
# Learning Finished
# iteration  135
# Observing Finished
# Cost 0.00568861
# Cost 0.00175428
# Cost 0.00461938
# Cost 0.00208364
# Cost 0.00432722
# Learning Finished
# iteration  136
# Observing Finished
# Cost 0.00239628
# Cost 0.00220492
# Cost 0.00114745
# Cost 0.00341174
# Cost 0.00160894
# Learning Finished
# iteration  137
# Observing Finished
# Cost 0.00198261
# Cost 0.00347403
# Cost 0.00125597
# Cost 0.00155201
# Cost 0.000932391
# Learning Finished
# iteration  138
# Observing Finished
# Cost 0.00652445
# Cost 0.00836217
# Cost 0.0122734
# Cost 0.00582136
# Cost 0.00438099
# Learning Finished
# iteration  139
# Observing Finished
# Cost 0.000985911
# Cost 0.00276409
# Cost 0.00197578
# Cost 0.00318425
# Cost 0.0011563
# Learning Finished
# iteration  140
# Observing Finished
# Cost 0.00161045
# Cost 0.00285883
# Cost 0.00114683
# Cost 0.00118638
# Cost 0.000598911
# Learning Finished
# iteration  141
# Observing Finished
# Cost 0.00105761
# Cost 0.00194293
# Cost 0.00260661
# Cost 0.00218008
# Cost 0.00436027
# Learning Finished
# iteration  142
# Observing Finished
# Cost 0.00477716
# Cost 0.0035369
# Cost 0.0695761
# Cost 0.00636617
# Cost 0.00536151
# Learning Finished
# iteration  143
# Observing Finished
# Cost 0.00185018
# Cost 0.000826074
# Cost 0.00254392
# Cost 0.0020782
# Cost 0.00188381
# Learning Finished
# iteration  144
# Observing Finished
# Cost 0.00302437
# Cost 0.00485409
# Cost 0.00241082
# Cost 0.00292189
# Cost 0.00521147
# Learning Finished
# iteration  145
# Observing Finished
# Cost 0.00224463
# Cost 0.00137113
# Cost 0.00253313
# Cost 0.00336552
# Cost 0.00311718
# Learning Finished
# iteration  146
# Observing Finished
# Cost 0.00170513
# Cost 0.00297512
# Cost 0.00168694
# Cost 0.00233176
# Cost 0.00224551
# Learning Finished
# iteration  147
# Observing Finished
# Cost 0.00311034
# Cost 0.00564972
# Cost 0.011226
# Cost 0.0052541
# Cost 0.00244294
# Learning Finished
# iteration  148
# Observing Finished
# Cost 0.00486661
# Cost 0.00231066
# Cost 0.00320181
# Cost 0.00166035
# Cost 0.00322287
# Learning Finished
# iteration  149
# Observing Finished
# Cost 0.00101812
# Cost 0.0012502
# Cost 0.00128305
# Cost 0.00137995
# Cost 0.00114281
# Learning Finished
# iteration  150
# Observing Finished
# Cost 0.0013885
# Cost 0.000587416
# Cost 0.00312707
# Cost 0.00364834
# Cost 0.00864114
# Learning Finished
# iteration  151
# Observing Finished
# Cost 0.00243358
# Cost 0.00149316
# Cost 0.0030889
# Cost 0.00172337
# Cost 0.000874026
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [0]    reward  0.02 state [[  1.           9.          13.           2.          12.04159451]] False
# Game :  [0]    reward  0.02 state [[  1.           8.          13.           3.          11.04536057]] False
# Game :  [0]    reward  0.02 state [[  1.           7.          13.           4.          10.04987526]] False
# Game :  [0]    reward  0.02 state [[  1.           6.          13.           5.           9.05538559]] False
# Game :  [0]    reward  0.02 state [[ 1.          5.          6.          6.          8.06225777]] False
# Game :  [0]    reward  0.02 state [[ 1.          4.          5.          7.          7.07106781]] False
# Game :  [0]    reward  0.02 state [[ 1.          3.          2.          8.          6.08276272]] False
# Game :  [0]    reward  0.02 state [[  1.           2.          13.           9.           5.09901953]] False
# Game :  [3]    reward  0.02 state [[  1.           1.          13.          10.           4.12310553]] False
# Game :  [3]    reward  0.02 state [[  2.           1.          12.          10.           4.47213602]] False
# Game :  [3]    reward  0.02 state [[  3.   0.  11.  10.   5.]] False
# Game :  [3]    reward  0.02 state [[  4.          -3.          10.          10.           5.65685415]] False
# Game :  [3]    reward  0.02 state [[  5.           4.           9.          10.           6.40312433]] False
# Game :  [3]    reward  0.02 state [[  6.           0.           8.          10.           7.21110249]] False
# Game :  [3]    reward  0.02 state [[  7.          -4.           7.          10.           8.06225777]] False
# Game :  [3]    reward  0.02 state [[  8.          -5.           6.          10.           8.94427204]] False
# Game :  [3]    reward  0.02 state [[  9.           4.           5.          10.           9.84885788]] False
# Game :  [0]    reward  0.02 state [[ 10.           4.           4.          10.          10.77032948]] False
# Game :  [0]    reward  0.02 state [[  3.           3.           4.          11.          10.44030666]] False
# Game :  [3]    reward  0.02 state [[  7.           2.           4.          12.          10.19803905]] False
# Game :  [0]    reward  0.02 state [[  8.           2.           3.          12.          11.18033981]] False
# Game :  [0]    reward  0.02 state [[  6.           1.           3.          13.          11.04536057]] False
# Game :  [3]    reward  0.02 state [[ 11.   0.   3.  14.  11.]] False
# Game :  [3]    reward  0.02 state [[ 12.   0.   2.  14.  12.]] False
# Game :  [3]    reward  0.02 state [[ 13.   0.   1.  14.  13.]] False
# Game :  [3]    reward  -0.5 state [[ 14.   0.   0.  14.  14.]] True
# Game ended! Total reward: 0.060000000000000164
# iteration  152
# Observing Finished
# Cost 0.00418244
# Cost 0.00133816
# Cost 0.00336736
# Cost 0.00290223
# Cost 0.00126627
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [0]    reward  0.02 state [[  0.   1.   0.  13.   1.]] False
# Game :  [3]    reward  0.02 state [[  0.   0.  14.  14.   0.]] False
# Game :  [3]    reward  0.02 state [[  1.  -3.  13.  14.   1.]] False
# Game :  [3]    reward  0.02 state [[  2.  -3.  12.  14.   2.]] False
# Game :  [3]    reward  0.02 state [[  3.  -4.  11.  14.   3.]] False
# Game :  [3]    reward  0.02 state [[  4.  -7.  10.  14.   4.]] False
# Game :  [3]    reward  0.02 state [[  5.   0.   9.  14.   5.]] False
# Game :  [3]    reward  0.02 state [[  6.  -4.   8.  14.   6.]] False
# Game :  [3]    reward  0.02 state [[  7.  -8.   7.  14.   7.]] False
# Game :  [3]    reward  0.02 state [[  8.  -9.   6.  14.   8.]] False
# Game :  [3]    reward  0.02 state [[  9.   0.   5.  14.   9.]] False
# Game :  [3]    reward  0.02 state [[ 10.   0.   4.  14.  10.]] False
# Game :  [3]    reward  0.02 state [[ 11.   0.   3.  14.  11.]] False
# Game :  [3]    reward  0.02 state [[ 12.   0.   2.  14.  12.]] False
# Game :  [3]    reward  0.02 state [[ 13.   0.   1.  14.  13.]] False
# Game :  [3]    reward  -0.5 state [[ 14.   0.   0.  14.  14.]] True
# Game ended! Total reward: 0.060000000000000164
# iteration  153
# Observing Finished
# Cost 0.00362028
# Cost 0.000515146
# Cost 0.00171869
# Cost 0.00101291
# Cost 0.000991724
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [0]    reward  0.02 state [[  0.   1.   0.  13.   1.]] False
# Game :  [3]    reward  0.02 state [[  0.   0.  14.  14.   0.]] False
# Game :  [3]    reward  0.02 state [[  1.  -3.  13.  14.   1.]] False
# Game :  [3]    reward  0.02 state [[  2.  -3.  12.  14.   2.]] False
# Game :  [3]    reward  0.02 state [[  3.  -4.  11.  14.   3.]] False
# Game :  [3]    reward  0.02 state [[  4.  -7.  10.  14.   4.]] False
# Game :  [3]    reward  0.02 state [[  5.   0.   9.  14.   5.]] False
# Game :  [3]    reward  0.02 state [[  6.  -4.   8.  14.   6.]] False
# Game :  [3]    reward  0.02 state [[  7.  -8.   7.  14.   7.]] False
# Game :  [3]    reward  0.02 state [[  8.  -9.   6.  14.   8.]] False
# Game :  [3]    reward  0.02 state [[  9.   0.   5.  14.   9.]] False
# Game :  [3]    reward  0.02 state [[ 10.   0.   4.  14.  10.]] False
# Game :  [3]    reward  0.02 state [[ 11.   0.   3.  14.  11.]] False
# Game :  [3]    reward  0.02 state [[ 12.   0.   2.  14.  12.]] False
# Game :  [3]    reward  0.02 state [[ 13.   0.   1.  14.  13.]] False
# Game :  [3]    reward  -0.5 state [[ 14.   0.   0.  14.  14.]] True
# Game ended! Total reward: 0.060000000000000164
# iteration  154
# Observing Finished
# Cost 0.000670326
# Cost 0.00297194
# Cost 0.00128983
# Cost 0.00170409
# Cost 0.00109324
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [3]    reward  -0.5 state [[  0.   1.   0.  13.   1.]] True
# Game ended! Total reward: -0.24000000000000005
# iteration  155
# Observing Finished
# Cost 0.00183595
# Cost 0.00165951
# Cost 0.00128883
# Cost 0.000735033
# Cost 0.00104608
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [3]    reward  -0.5 state [[  0.   2.   0.  12.   2.]] True
# Game ended! Total reward: -0.26
# iteration  156
# Observing Finished
# Cost 0.00179743
# Cost 0.00145829
# Cost 0.00225161
# Cost 0.00148445
# Cost 0.00106347
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [2]    reward  -0.5 state [[  0.   1.   0.  13.   1.]] True
# Game ended! Total reward: -0.24000000000000005
# iteration  157
# Observing Finished
# Cost 0.00202021
# Cost 0.00861312
# Cost 0.00733775
# Cost 0.00366003
# Cost 0.00324138
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [3]    reward  -0.5 state [[  0.   1.   0.  13.   1.]] True
# Game ended! Total reward: -0.24000000000000005
# iteration  158
# Observing Finished
# Cost 0.00140608
# Cost 0.00116369
# Cost 0.000945441
# Cost 0.000668405
# Cost 0.000963563
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game ended! Total reward: -7.140000000000004
# iteration  159
# Observing Finished
# Cost 0.00826093
# Cost 0.0140389
# Cost 0.0127341
# Cost 0.0075781
# Cost 0.00557299
# Learning Finished
# Evaluating
# Game :  [2]    reward  -0.5 state [[  0.  14.  14.   0.  14.]] True
# Game ended! Total reward: -0.5
# iteration  160
# Observing Finished
# Cost 0.00519568
# Cost 0.0104407
# Cost 0.030513
# Cost 0.0138117
# Cost 0.00732097
# Learning Finished
# Evaluating
# Game :  [1]    reward  -0.5 state [[  0.  14.  14.   0.  14.]] True
# Game ended! Total reward: -0.5
# iteration  161
# Observing Finished
# Cost 0.0012799
# Cost 0.00091562
# Cost 0.000521075
# Cost 0.00102752
# Cost 0.00119793
# Learning Finished
# Evaluating
# Game :  [3]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  1.          11.          13.           0.          14.03566837]] False
# Game :  [0]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [0]    reward  0.02 state [[  1.           9.          13.           2.          12.04159451]] False
# Game :  [0]    reward  0.02 state [[  1.           8.          13.           3.          11.04536057]] False
# Game :  [0]    reward  0.02 state [[  1.           7.          13.           4.          10.04987526]] False
# Game :  [0]    reward  0.02 state [[  1.           6.          13.           5.           9.05538559]] False
# Game :  [0]    reward  0.02 state [[ 1.          5.          6.          6.          8.06225777]] False
# Game :  [0]    reward  0.02 state [[ 1.          4.          5.          7.          7.07106781]] False
# Game :  [0]    reward  0.02 state [[ 1.          3.          2.          8.          6.08276272]] False
# Game :  [3]    reward  0.02 state [[  1.           2.          13.           9.           5.09901953]] False
# Game :  [3]    reward  0.02 state [[  2.           2.          12.           9.           5.38516474]] False
# Game :  [1]    reward  0.02 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game :  [1]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [0]    reward  -0.2 state [[ 3.          2.          0.          8.          6.70820379]] False
# Game ended! Total reward: -7.140000000000004
# iteration  162
# Observing Finished
# Cost 0.000934391
# Cost 0.0012482
# Cost 0.000853807
# Cost 0.00134055
# Cost 0.00117429
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [0]    reward  0.02 state [[  0.  12.  14.   2.  12.]] False
# Game :  [0]    reward  0.02 state [[  0.  11.  14.   3.  11.]] False
# Game :  [0]    reward  0.02 state [[  0.  10.  14.   4.  10.]] False
# Game :  [0]    reward  0.02 state [[  0.   9.  14.   5.   9.]] False
# Game :  [0]    reward  0.02 state [[ 0.  8.  7.  6.  8.]] False
# Game :  [0]    reward  0.02 state [[ 0.  7.  6.  7.  7.]] False
# Game :  [0]    reward  0.02 state [[ 0.  6.  3.  8.  6.]] False
# Game :  [0]    reward  0.02 state [[  0.   5.  14.   9.   5.]] False
# Game :  [0]    reward  0.02 state [[  0.   4.  14.  10.   4.]] False
# Game :  [0]    reward  0.02 state [[  0.   3.   2.  11.   3.]] False
# Game :  [0]    reward  0.02 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game :  [0]    reward  -0.2 state [[  0.   2.   0.  12.   2.]] False
# Game :  [1]    reward  -0.2 state [[  0.   1.   0.  13.   1.]] False
# Game ended! Total reward: -7.140000000000004
# iteration  163
# Observing Finished
# Cost 0.0052963
# Cost 0.0082617
# Cost 0.00548576
# Cost 0.00469797
# Cost 0.00326019
# Learning Finished
# Evaluating
# Game :  [2]    reward  -0.5 state [[  0.  14.  14.   0.  14.]] True
# Game ended! Total reward: -0.5
# iteration  164
# Observing Finished
# Cost 0.0049085
# Cost 0.00670993
# Cost 0.0189558
# Cost 0.0263182
# Cost 0.0152109
# Learning Finished
# Evaluating
# Game :  [1]    reward  -0.5 state [[  0.  14.  14.   0.  14.]] True
# Game ended! Total reward: -0.5
# iteration  165
# Observing Finished
# Cost 0.00652544
# Cost 0.00781911
# Cost 0.00698331
# Cost 0.00723708
# Cost 0.00604467
# Learning Finished
# Evaluating
# Game :  [3]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [0]    reward  0.02 state [[  1.          11.          13.           0.          14.03566837]] False
# Game :  [0]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [0]    reward  0.02 state [[  1.           9.          13.           2.          12.04159451]] False
# Game :  [0]    reward  0.02 state [[  1.           8.          13.           3.          11.04536057]] False
# Game :  [0]    reward  0.02 state [[  1.           7.          13.           4.          10.04987526]] False
# Game :  [0]    reward  0.02 state [[  1.           6.          13.           5.           9.05538559]] False
# Game :  [0]    reward  0.02 state [[ 1.          5.          6.          6.          8.06225777]] False
# Game :  [0]    reward  0.02 state [[ 1.          4.          5.          7.          7.07106781]] False
# Game :  [0]    reward  0.02 state [[ 1.          3.          2.          8.          6.08276272]] False
# Game :  [3]    reward  0.02 state [[  1.           2.          13.           9.           5.09901953]] False
# Game :  [3]    reward  0.02 state [[  2.           2.          12.           9.           5.38516474]] False
# Game :  [3]    reward  0.02 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# Game :  [2]    reward  -0.2 state [[  4.          -2.          10.           9.           6.40312433]] False
# Game :  [3]    reward  -0.2 state [[  3.           1.          11.           9.           5.83095169]] False
# ...
# Cost 0.00334137
# Cost 0.00350726
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [3]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [3]    reward  0.02 state [[  2.          10.          12.           1.          13.15294647]] False
# Game :  [3]    reward  0.02 state [[  3.           9.          11.           1.          13.34166431]] False
# Game :  [3]    reward  0.02 state [[  4.           6.          10.           1.          13.60147095]] False
# Game :  [3]    reward  0.02 state [[  5.         13.          9.          1.         13.9283886]] False
# Game :  [0]    reward  0.02 state [[  6.          9.          8.          1.         14.3178215]] False
# Game :  [0]    reward  0.02 state [[  6.           8.           8.           2.          13.41640759]] False
# Game :  [0]    reward  0.02 state [[  6.           7.           8.           3.          12.52996445]] False
# Game :  [0]    reward  0.02 state [[  6.           6.           8.           4.          11.66190338]] False
# Game :  [0]    reward  0.02 state [[  6.           5.           8.           5.          10.81665421]] False
# Game :  [0]    reward  0.02 state [[  6.   4.   1.   6.  10.]] False
# Game :  [0]    reward  0.02 state [[ 6.          3.          0.          7.          9.21954441]] False
# Game :  [0]    reward  0.02 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game ended! Total reward: -6.700000000000004
# iteration  195
# Observing Finished
# Cost 0.000701154
# Cost 0.000357862
# Cost 0.000330498
# Cost 0.000348883
# Cost 0.00054329
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [3]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [3]    reward  0.02 state [[  2.          10.          12.           1.          13.15294647]] False
# Game :  [3]    reward  0.02 state [[  3.           9.          11.           1.          13.34166431]] False
# Game :  [3]    reward  0.02 state [[  4.           6.          10.           1.          13.60147095]] False
# Game :  [3]    reward  0.02 state [[  5.         13.          9.          1.         13.9283886]] False
# Game :  [0]    reward  0.02 state [[  6.          9.          8.          1.         14.3178215]] False
# Game :  [0]    reward  0.02 state [[  6.           8.           8.           2.          13.41640759]] False
# Game :  [0]    reward  0.02 state [[  6.           7.           8.           3.          12.52996445]] False
# Game :  [0]    reward  0.02 state [[  6.           6.           8.           4.          11.66190338]] False
# Game :  [0]    reward  0.02 state [[  6.           5.           8.           5.          10.81665421]] False
# Game :  [0]    reward  0.02 state [[  6.   4.   1.   6.  10.]] False
# Game :  [0]    reward  0.02 state [[ 6.          3.          0.          7.          9.21954441]] False
# Game :  [0]    reward  0.02 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game :  [0]    reward  -0.2 state [[ 1.          2.          8.          8.          8.48528099]] False
# Game :  [1]    reward  -0.2 state [[ 6.          1.          8.          9.          7.81024981]] False
# Game ended! Total reward: -6.700000000000004
# iteration  196
# Observing Finished
# Cost 0.00035375
# Cost 0.000192344
# Cost 0.000150934
# Cost 0.000173668
# Cost 0.000145826
# Learning Finished
# Evaluating
# Game :  [0]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  0.  13.  14.   1.  13.]] False
# Game :  [3]    reward  0.02 state [[  1.          10.          13.           1.          13.03840446]] False
# Game :  [3]    reward  0.02 state [[  2.          10.          12.           1.          13.15294647]] False
# Game :  [3]    reward  0.02 state [[  3.           9.          11.           1.          13.34166431]] False
# Game :  [3]    reward  0.02 state [[  4.           6.          10.           1.          13.60147095]] False
# Game :  [3]    reward  0.02 state [[  5.         13.          9.          1.         13.9283886]] False
# Game :  [3]    reward  0.02 state [[  6.          9.          8.          1.         14.3178215]] False
# Game :  [0]    reward  0.02 state [[  7.           5.           7.           1.          14.76482296]] False
# Game :  [0]    reward  0.02 state [[  7.           4.           7.           2.          13.89244366]] False
# Game :  [0]    reward  0.02 state [[  7.           3.           7.           3.          13.03840446]] False
# Game :  [0]    reward  0.02 state [[  7.           2.           7.           4.          12.20655537]] False
# Game :  [0]    reward  0.02 state [[  7.           1.           7.           5.          11.40175438]] False
# Game :  [0]    reward  -0.5 state [[  7.           0.           0.           6.          10.63014603]] True
# Game ended! Total reward: -0.24000000000000005
# iteration  197
# Observing Finished
# Cost 0.00874033
# Cost 0.0118879
# Cost 0.0146286
# Cost 0.0449374
# Cost 0.0221536
# Learning Finished
# Evaluating
# Game :  [1]    reward  -0.5 state [[  0.  14.  14.   0.  14.]] True
# Game ended! Total reward: -0.5
# iteration  198
# Observing Finished
# Cost 0.0019496
# Cost 0.00268676
# Cost 0.00141217
# Cost 0.00153397
# Cost 0.0012115
# Learning Finished
# Evaluating
# Game :  [3]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  1.          11.          13.           0.          14.03566837]] False
# Game :  [3]    reward  0.02 state [[  2.          11.          12.           0.          14.14213562]] False
# Game :  [3]    reward  0.02 state [[  3.         10.         11.          0.         14.3178215]] False
# Game :  [3]    reward  0.02 state [[  4.           7.          10.           0.          14.56021976]] False
# Game :  [3]    reward  0.02 state [[  5.          14.           9.           0.          14.86606884]] False
# Game :  [3]    reward  0.02 state [[  6.         10.          8.          0.         15.2315464]] False
# Game :  [3]    reward  0.02 state [[  7.           6.           7.           0.          15.65247631]] False
# Game :  [3]    reward  0.02 state [[  8.           5.           6.           0.          16.12451553]] False
# Game :  [3]    reward  0.02 state [[  9.          14.           5.           0.          16.64331627]] False
# Game :  [3]    reward  0.02 state [[ 10.          14.           4.           0.          17.20465088]] False
# Game :  [3]    reward  0.02 state [[ 11.          14.           3.           0.          17.80449295]] False
# Game :  [3]    reward  0.02 state [[ 12.          14.           2.           0.          18.43908882]] False
# Game :  [3]    reward  0.02 state [[ 13.          14.           1.           0.          19.10497284]] False
# Game :  [3]    reward  -0.5 state [[ 14.          14.           0.           0.          19.79899025]] True
# Game ended! Total reward: -0.22000000000000003
# iteration  199
# Observing Finished
# Cost 4.70252e-05
# Cost 4.02989e-05
# Cost 6.27112e-05
# Cost 3.38383e-05
# Cost 5.55564e-05
# Learning Finished
# Evaluating
# Game :  [3]    reward  0.02 state [[  0.  14.  14.   0.  14.]] False
# Game :  [3]    reward  0.02 state [[  1.          11.          13.           0.          14.03566837]] False
# Game :  [3]    reward  0.02 state [[  2.          11.          12.           0.          14.14213562]] False
# Game :  [3]    reward  0.02 state [[  3.         10.         11.          0.         14.3178215]] False
# Game :  [3]    reward  0.02 state [[  4.           7.          10.           0.          14.56021976]] False
# Game :  [3]    reward  0.02 state [[  5.          14.           9.           0.          14.86606884]] False
# Game :  [3]    reward  0.02 state [[  6.         10.          8.          0.         15.2315464]] False
# Game :  [3]    reward  0.02 state [[  7.           6.           7.           0.          15.65247631]] False
# Game :  [3]    reward  0.02 state [[  8.           5.           6.           0.          16.12451553]] False
# Game :  [3]    reward  0.02 state [[  9.          14.           5.           0.          16.64331627]] False
# Game :  [3]    reward  0.02 state [[ 10.          14.           4.           0.          17.20465088]] False
# Game :  [3]    reward  0.02 state [[ 11.          14.           3.           0.          17.80449295]] False
# Game :  [3]    reward  0.02 state [[ 12.          14.           2.           0.          18.43908882]] False
# Game :  [3]    reward  0.02 state [[ 13.          14.           1.           0.          19.10497284]] False
# Game :  [3]    reward  -0.5 state [[ 14.          14.           0.           0.          19.79899025]] True
# Game ended! Total reward: -0.22000000000000003
